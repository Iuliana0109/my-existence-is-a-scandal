# %% [markdown]
# #LAB 5: Floyd and Djikstra Alg

# %%
import math
import copy
import time

def time_ms():
    return time.time() * 1000

class Graph :

    def __init__(self, vertices) :
        """Initializes a weighted adjacency matrix for a graph with size nodes.
        Graph is initialized with nr of vertices and 0 edges.     
        Keyword arguments:
        vertices -- Number of nodes of the graph."""     
        self.V = vertices   
        self.graph = [] #the list of lists
        for i in range(self.V):
            row_i = []
            for j in range(self.V) :
                if i == j: 
                    row_i.append(0)
                else : 
                    row_i.append(math.inf)
            self.graph.append(row_i)  
        
    def addEdge(self, u, v, w):
        self.graph[u][v] = w
        
    def printSolution(self, dist):
        print("Weighted Adjacency Matrix:")
        for i in range(len(dist)):
            for j in range(len(dist)):
                print(dist[i][j], ' ', end=' ')
            print() 
        
    def floyd_warshall(self) :
        dist = copy.deepcopy(self.graph)
        n = len(dist)   
        for k in range(n) :
            for i in range(n) :
                for j in range(n) :
                    dist[i][j] = min(dist[i][j], dist[i][k] + dist[k][j])
        return self.printSolution(dist)
# Out:
# Weighted Adjacency Matrix:
# 0   4   8   4   10   9   12   9   13   10   6   8   7   9   11   11   12   11   13   13
# 4   0   4   4   6   5   8   9   10   10   2   4   3   5   7   7   12   11   13   9
# 8   4   0   8   2   1   4   10   6   8   6   8   7   9   8   9   10   9   11   11
# 1   4   8   0   10   9   12   5   9   6   6   8   7   9   11   11   8   7   9   11
# 10   6   2   10   0   3   2   8   5   6   8   9   9   8   6   7   8   7   9   9
# 9   5   1   9   3   0   3   9   5   7   7   8   8   9   7   8   9   8   10   10
# 11   8   4   10   2   3   0   6   3   4   9   7   10   6   4   5   6   5   7   7
# 6   9   11   5   10   10   8   0   5   2   11   13   12   12   10   9   4   3   5   7
# 10   10   6   9   5   5   3   5   0   3   12   10   13   9   7   8   5   4   6   8
# 7   10   9   6   8   8   6   2   3   0   12   11   13   10   8   7   2   1   3   5
# 6   2   6   6   8   7   9   11   12   12   0   2   1   3   5   5   14   11   13   7
# 8   4   8   8   9   8   7   13   10   11   2   0   3   1   3   4   13   10   12   6
# 7   3   7   7   9   8   9   12   12   11   1   3   0   4   5   4   13   10   12   6
# 9   5   9   9   8   9   6   12   9   10   3   1   4   0   2   3   12   9   11   5
# 11   7   8   11   6   7   4   10   7   8   5   3   6   2   0   1   10   7   9   3
# 12   8   9   12   7   8   5   9   8   7   6   4   7   3   1   0   9   6   8   2
# 9   12   11   8   10   10   8   4   5   2   14   13   15   12   10   9   0   3   5   7
# 8   11   10   7   9   9   7   3   4   1   12   10   13   9   7   6   3   0   2   4
# 10   13   12   9   11   11   9   5   6   3   14   12   15   11   9   8   5   2   0   6
# 12   10   11   11   9   10   7   7   8   5   8   6   9   5   3   2   7   4   6   0
#
# The time of execution for Floyd's Algorithm: 69.9208984375

# %%
import time
import matplotlib.pyplot as plt


g1 = Graph(6)
g1.addEdge(0, 1, 4), g1.addEdge(0, 3, 4),
g1.addEdge(1, 0, 2), g1.addEdge(1, 2, 4), g1.addEdge(1, 3, 4), 
g1.addEdge(2, 1, 4), g1.addEdge(2, 4, 10), g1.addEdge(2, 5, 1),
g1.addEdge(3, 0, 1), g1.addEdge(3, 1, 4), g1.addEdge(3, 5, 4)
g1.addEdge(4, 2, 10),
g1.addEdge(5, 2, 1), g1.addEdge(5, 3, 4)
start1 = time_ms()  
dist1 = g1.floyd_warshall()
end1 = time_ms()
        
g = Graph(8)
g.addEdge(0, 1, 4), g.addEdge(0, 3, 2),
g.addEdge(1, 0, 2), g.addEdge(1, 2, 4), g.addEdge(1, 3, 4), 
g.addEdge(2, 1, 4), g.addEdge(2, 4, 10), g.addEdge(2, 5, 1),
g.addEdge(3, 0, 2), g.addEdge(3, 1, 4), g.addEdge(3, 7, 5),
g.addEdge(4, 2, 2), g.addEdge(4, 6, 12),
g.addEdge(5, 2, 1), g.addEdge(5, 6, 3), g.addEdge(5, 7, 6)
g.addEdge(6, 4, 4), g.addEdge(6, 5, 1), 
g.addEdge(7, 3, 5), g.addEdge(7, 5, 6)
start2 = time_ms()  
dist2 = g.floyd_warshall()
end2 = time_ms()

g3 = Graph(10)
g3.addEdge(0, 1, 4), g3.addEdge(0, 3, 4),
g3.addEdge(1, 0, 4), g3.addEdge(1, 2, 4), g3.addEdge(1, 3, 4), g3.addEdge(1, 9, 7),
g3.addEdge(2, 1, 4), g3.addEdge(2, 4, 2), g3.addEdge(2, 5, 1),
g3.addEdge(3, 0, 1), g3.addEdge(3, 1, 4), g3.addEdge(3, 7, 4), g3.addEdge(3, 9, 6),
g3.addEdge(4, 2, 2), g3.addEdge(4, 6, 2),
g3.addEdge(5, 2, 1), g3.addEdge(5, 6, 3), g3.addEdge(5, 8, 5),
g3.addEdge(6, 4, 2), g3.addEdge(6, 5, 3), g3.addEdge(6, 8, 3), g3.addEdge(6, 9, 4),
g3.addEdge(7, 3, 4), g3.addEdge(7, 9, 1), 
g3.addEdge(8, 5, 5), g3.addEdge(8, 6, 3), g3.addEdge(8, 9, 3),
g3.addEdge(9, 1, 7), g3.addEdge(9, 3, 6), g3.addEdge(9, 7, 1), g3.addEdge(9, 8, 3)
start3 = time_ms()  
dist3 = g3.floyd_warshall()
end3 = time_ms()

g4 = Graph(12)
g4.addEdge(0, 1, 4), g4.addEdge(0, 3, 4),
g4.addEdge(1, 0, 4), g4.addEdge(1, 2, 4), g4.addEdge(1, 3, 4), g4.addEdge(1, 9, 10), g4.addEdge(1, 10, 2),
g4.addEdge(2, 1, 4), g4.addEdge(2, 4, 5), g4.addEdge(2, 5, 1),
g4.addEdge(3, 0, 1), g4.addEdge(3, 1, 4), g4.addEdge(3, 7, 5), g4.addEdge(3, 9, 6),
g4.addEdge(4, 2, 5), g4.addEdge(4, 6, 2), 
g4.addEdge(5, 2, 1), g4.addEdge(5, 6, 3), g4.addEdge(5, 8, 5), g4.addEdge(5, 11, 8),
g4.addEdge(6, 4, 2), g4.addEdge(6, 5, 3), g4.addEdge(6, 8, 3), g4.addEdge(6, 9, 4), 
g4.addEdge(7, 3, 5), g4.addEdge(7, 9, 2), g4.addEdge(7, 11, 2)
g4.addEdge(8, 5, 5), g4.addEdge(8, 6, 3), g4.addEdge(8, 9, 3),
g4.addEdge(9, 1, 10), g4.addEdge(9, 3, 6), g4.addEdge(9, 7, 2), g4.addEdge(9, 8, 3), 
g4.addEdge(10, 1, 2), g4.addEdge(10, 11, 2)
g4.addEdge(11, 5, 8),  g4.addEdge(11, 7, 2), g4.addEdge(11, 10, 2)
start4 = time_ms()  
dist4 = g4.floyd_warshall()
end4 = time_ms()

g5 = Graph(14)
g5.addEdge(0, 1, 4), g5.addEdge(0, 3, 4),
g5.addEdge(1, 0, 4), g5.addEdge(1, 2, 4), g5.addEdge(1, 3, 4), g5.addEdge(1, 9, 10), g5.addEdge(1, 10, 2), g5.addEdge(1, 13, 10)
g5.addEdge(2, 1, 4), g5.addEdge(2, 4, 2), g5.addEdge(2, 5, 1),
g5.addEdge(3, 0, 1), g5.addEdge(3, 1, 4), g5.addEdge(3, 7, 5), g5.addEdge(3, 9, 6),
g5.addEdge(4, 2, 2), g5.addEdge(4, 6, 2), g5.addEdge(4, 12, 12),
g5.addEdge(5, 2, 1), g5.addEdge(5, 6, 4), g5.addEdge(5, 7, 2),g5.addEdge(5, 8, 5), g5.addEdge(5, 11, 8),
g5.addEdge(6, 4, 2), g5.addEdge(6, 5, 4), g5.addEdge(6, 8, 3), g5.addEdge(6, 9, 4),
g5.addEdge(7, 3, 5), g5.addEdge(7, 9, 2), g5.addEdge(7, 5, 2)
g5.addEdge(8, 5, 5), g5.addEdge(8, 6, 3), g5.addEdge(8, 9, 3),
g5.addEdge(9, 1, 10), g5.addEdge(9, 3, 6), g5.addEdge(9, 7, 2), g5.addEdge(9, 8, 3)
g5.addEdge(10, 1, 2), g5.addEdge(10, 11, 2), g5.addEdge(10, 12, 1), 
g5.addEdge(11, 5, 8), g5.addEdge(11, 10, 2), g5.addEdge(11, 12, 3), g5.addEdge(11, 13, 1), 
g5.addEdge(12, 4, 12), g5.addEdge(12, 10, 1), g5.addEdge(12, 11, 3)
g5.addEdge(13, 11, 1), g5.addEdge(13, 1, 10)
start5 = time_ms()  
dist5 = g5.floyd_warshall()
end5 = time_ms()

g6 = Graph(16)
g6.addEdge(0, 1, 4), g6.addEdge(0, 3, 4),
g6.addEdge(1, 0, 4), g6.addEdge(1, 2, 4), g6.addEdge(1, 3, 4), g6.addEdge(1, 9, 10), g6.addEdge(1, 10, 2),
g6.addEdge(2, 1, 4), g6.addEdge(2, 4, 2), g6.addEdge(2, 5, 1),
g6.addEdge(3, 0, 1), g6.addEdge(3, 1, 4), g6.addEdge(3, 7, 5), g6.addEdge(3, 9, 6),
g6.addEdge(4, 2, 2), g6.addEdge(4, 6, 2), g6.addEdge(4, 12, 12), g6.addEdge(4, 14, 6),
g6.addEdge(5, 2, 1), g6.addEdge(5, 6, 3), g6.addEdge(5, 8, 5), g6.addEdge(5, 11, 8),
g6.addEdge(6, 4, 2), g6.addEdge(6, 5, 3), g6.addEdge(6, 8, 3), g6.addEdge(6, 9, 4), g6.addEdge(6, 14, 4),
g6.addEdge(7, 3, 5), g6.addEdge(7, 9, 2),
g6.addEdge(8, 5, 5), g6.addEdge(8, 6, 3), g6.addEdge(8, 9, 3),
g6.addEdge(9, 1, 10), g6.addEdge(9, 3, 6), g6.addEdge(9, 7, 2), g6.addEdge(9, 8, 3),
g6.addEdge(10, 1, 2), g6.addEdge(10, 11, 2), g6.addEdge(10, 12, 1), 
g6.addEdge(11, 5, 8), g6.addEdge(11, 10, 2), g6.addEdge(11, 12, 3), g6.addEdge(11, 13, 1), 
g6.addEdge(12, 4, 12), g6.addEdge(12, 10, 1), g6.addEdge(12, 11, 3), g6.addEdge(12, 15, 4),
g6.addEdge(13, 11, 1), g6.addEdge(13, 14, 2), g6.addEdge(13, 15, 2)
g6.addEdge(14, 4, 6), g6.addEdge(14, 6, 4), g6.addEdge(14, 13, 2), g6.addEdge(14, 15, 1)
g6.addEdge(15, 14, 1), g6.addEdge(15, 13, 2)
start6 = time_ms()  
dist6 = g6.floyd_warshall()
end6 = time_ms()

g7 = Graph(18)
g7.addEdge(0, 1, 4), g7.addEdge(0, 3, 4),
g7.addEdge(1, 0, 4), g7.addEdge(1, 2, 4), g7.addEdge(1, 3, 4), g7.addEdge(1, 9, 10), g7.addEdge(1, 10, 2),
g7.addEdge(2, 1, 4), g7.addEdge(2, 4, 2), g7.addEdge(2, 5, 1),
g7.addEdge(3, 0, 1), g7.addEdge(3, 1, 4), g7.addEdge(3, 7, 5), g7.addEdge(3, 9, 6),
g7.addEdge(4, 2, 2), g7.addEdge(4, 6, 2), g7.addEdge(4, 12, 12), g7.addEdge(4, 14, 6), g7.addEdge(4, 17, 16)
g7.addEdge(5, 2, 1), g7.addEdge(5, 6, 3), g7.addEdge(5, 8, 5), g7.addEdge(5, 11, 8),
g7.addEdge(6, 4, 2), g7.addEdge(6, 5, 3), g7.addEdge(6, 8, 3), g7.addEdge(6, 9, 4), g7.addEdge(6, 14, 4),
g7.addEdge(7, 3, 5), g7.addEdge(7, 9, 2), g7.addEdge(7, 16, 6)
g7.addEdge(8, 5, 5), g7.addEdge(8, 6, 3), g7.addEdge(8, 9, 3),
g7.addEdge(9, 1, 10), g7.addEdge(9, 3, 6), g7.addEdge(9, 7, 2), g7.addEdge(9, 8, 3), g7.addEdge(9, 16, 2), g7.addEdge(9, 17, 1),
g7.addEdge(10, 1, 2), g7.addEdge(10, 11, 2), g7.addEdge(10, 12, 1), 
g7.addEdge(11, 5, 8), g7.addEdge(11, 10, 2), g7.addEdge(11, 12, 3), g7.addEdge(11, 13, 1), 
g7.addEdge(12, 4, 12), g7.addEdge(12, 10, 1), g7.addEdge(12, 11, 3), g7.addEdge(12, 15, 4),
g7.addEdge(13, 11, 1), g7.addEdge(13, 14, 2), g7.addEdge(13, 15, 2)
g7.addEdge(14, 4, 6), g7.addEdge(14, 6, 4), g7.addEdge(14, 13, 2), g7.addEdge(14, 15, 1),
g7.addEdge(15, 14, 1), g7.addEdge(15, 14, 1), g7.addEdge(15, 13, 2)
g7.addEdge(16, 7, 6), g7.addEdge(16, 9, 2), 
g7.addEdge(17, 9, 1), g7.addEdge(17, 4, 16)
start7 = time_ms()  
dist7 = g7.floyd_warshall()
end7 = time_ms()


g8 = Graph(20)
g8.addEdge(0, 1, 4), g8.addEdge(0, 3, 4),
g8.addEdge(1, 0, 4), g8.addEdge(1, 2, 4), g8.addEdge(1, 3, 4), g8.addEdge(1, 9, 10), g8.addEdge(1, 10, 2),
g8.addEdge(2, 1, 4), g8.addEdge(2, 4, 2), g8.addEdge(2, 5, 1),
g8.addEdge(3, 0, 1), g8.addEdge(3, 1, 4), g8.addEdge(3, 7, 5), g8.addEdge(3, 9, 6),
g8.addEdge(4, 2, 2), g8.addEdge(4, 6, 2), g8.addEdge(4, 12, 12), g8.addEdge(4, 14, 6),
g8.addEdge(5, 2, 1), g8.addEdge(5, 6, 3), g8.addEdge(5, 8, 5), g8.addEdge(5, 11, 8),
g8.addEdge(6, 4, 2), g8.addEdge(6, 5, 3), g8.addEdge(6, 8, 3), g8.addEdge(6, 9, 4), g8.addEdge(6, 14, 4),
g8.addEdge(7, 3, 5), g8.addEdge(7, 9, 2), g8.addEdge(7, 16, 6)
g8.addEdge(8, 5, 5), g8.addEdge(8, 6, 3), g8.addEdge(8, 9, 3),
g8.addEdge(9, 1, 10), g8.addEdge(9, 3, 6), g8.addEdge(9, 7, 2), g8.addEdge(9, 8, 3), g8.addEdge(9, 16, 2), g8.addEdge(9, 17, 1), g8.addEdge(9, 18, 5),
g8.addEdge(10, 1, 2), g8.addEdge(10, 11, 2), g8.addEdge(10, 12, 1), 
g8.addEdge(11, 5, 8), g8.addEdge(11, 10, 2), g8.addEdge(11, 12, 3), g8.addEdge(11, 13, 1), 
g8.addEdge(12, 4, 12), g8.addEdge(12, 10, 1), g8.addEdge(12, 11, 3), g8.addEdge(12, 15, 4),
g8.addEdge(13, 11, 1), g8.addEdge(13, 14, 2),
g8.addEdge(14, 4, 6), g8.addEdge(14, 6, 4), g8.addEdge(14, 13, 2), g8.addEdge(14, 15, 1), g8.addEdge(14, 18, 11),
g8.addEdge(15, 14, 1), g8.addEdge(15, 19, 2),
g8.addEdge(16, 7, 6), g8.addEdge(16, 9, 2), 
g8.addEdge(17, 9, 1), g8.addEdge(17, 18, 2), g8.addEdge(17, 19, 4),
g8.addEdge(18, 9, 5), g8.addEdge(18, 14, 11),  g8.addEdge(18, 17, 2)
g8.addEdge(19, 15, 2),  g8.addEdge(19, 17, 4)
start8 = time_ms()  
dist8 = g8.floyd_warshall()
end8 = time_ms()

x = [ 6, 8, 10, 12, 14, 16, 18, 20]
y2 = [ end1 - start1, end2-start2, end3 - start3, end4 - start4, end5 - start5, end6 - start6, end7 - start7, end8 - start8]
plt.plot(x, y2, marker='o')
plt.title('Floyd')
plt.show()
# Out:
# Weighted Adjacency Matrix:
# 0   4   8   4   18   8
# 2   0   4   4   14   5
# 6   4   0   5   10   1
# 1   4   5   0   15   4
# 16   14   10   15   0   11
# 5   5   1   4   11   0
# Weighted Adjacency Matrix:
# 0   4   8   2   16   9   12   7
# 2   0   4   4   12   5   8   9
# 6   4   0   8   8   1   4   7
# 2   4   8   0   16   9   12   5
# 8   6   2   10   0   3   6   9
# 7   5   1   9   7   0   3   6
# 8   6   2   10   4   1   0   7
# 7   9   7   5   13   6   9   0
# Weighted Adjacency Matrix:
# 0   4   8   4   10   9   12   8   12   9
# 4   0   4   4   6   5   8   8   10   7
# 8   4   0   8   2   1   4   9   6   8
# 1   4   8   0   10   9   11   4   8   5
# 10   6   2   10   0   3   2   7   5   6
# 9   5   1   9   3   0   3   8   5   7
# 10   8   4   9   2   3   0   5   3   4
# 5   8   10   4   9   9   7   0   4   1
# 9   10   6   8   5   5   3   4   0   3
# 6   7   9   5   8   8   6   1   3   0
# Weighted Adjacency Matrix:
# 0   4   8   4   13   9   12   9   13   10   6   8
# 4   0   4   4   9   5   8   6   10   8   2   4
# 8   4   0   8   5   1   4   10   6   8   6   8
# 1   4   8   0   13   9   12   5   9   6   6   7
# 13   9   5   12   0   5   2   8   5   6   11   10
# 9   5   1   9   5   0   3   9   5   7   7   8
# 11   8   4   10   2   3   0   6   3   4   10   8
# 6   6   10   5   10   10   8   0   5   2   4   2
# 10   10   6   9   5   5   3   5   0   3   9   7
# 7   8   9   6   8   8   6   2   3   0   6   4
# 6   2   6   6   11   7   10   4   9   6   0   2
# 8   4   8   7   12   8   10   2   7   4   2   0
# Weighted Adjacency Matrix:
# 0   4   8   4   10   9   12   9   13   10   6   8   7   9
# 4   0   4   4   6   5   8   7   10   9   2   4   3   5
# 8   4   0   8   2   1   4   3   6   5   6   8   7   9
# 1   4   8   0   10   7   11   5   9   6   6   8   7   9
# 10   6   2   10   0   3   2   5   5   6   8   10   9   11
# 8   5   1   7   3   0   4   2   5   4   7   8   8   9
# 11   8   4   10   2   4   0   6   3   4   10   12   11   13
# 6   7   3   5   5   2   6   0   5   2   9   10   10   11
# 10   10   6   9   5   5   3   5   0   3   12   13   13   14
# 7   9   5   6   7   4   6   2   3   0   11   12   12   13
# 6   2   6   6   8   7   10   9   12   11   0   2   1   3
# 8   4   8   8   10   8   12   10   13   12   2   0   3   1
# 7   3   7   7   9   8   11   10   13   12   1   3   0   4
# 9   5   9   9   11   9   13   11   14   13   3   1   4   0
# Weighted Adjacency Matrix:
# 0   4   8   4   10   9   12   9   13   10   6   8   7   9   11   11
# 4   0   4   4   6   5   8   9   10   10   2   4   3   5   7   7
# 8   4   0   8   2   1   4   10   6   8   6   8   7   9   8   9
# 1   4   8   0   10   9   12   5   9   6   6   8   7   9   11   11
# 10   6   2   10   0   3   2   8   5   6   8   9   9   8   6   7
# 9   5   1   9   3   0   3   9   5   7   7   8   8   9   7   8
# 11   8   4   10   2   3   0   6   3   4   9   7   10   6   4   5
# 6   9   11   5   10   10   8   0   5   2   11   13   12   14   12   13
# 10   10   6   9   5   5   3   5   0   3   12   10   13   9   7   8
# 7   10   9   6   8   8   6   2   3   0   12   13   13   12   10   11
# 6   2   6   6   8   7   9   11   12   12   0   2   1   3   5   5
# 8   4   8   8   9   8   7   13   10   11   2   0   3   1   3   3
# 7   3   7   7   9   8   9   12   12   13   1   3   0   4   5   4
# 9   5   9   9   8   9   6   12   9   10   3   1   4   0   2   2
# 11   7   8   11   6   7   4   10   7   8   5   3   6   2   0   1
# 11   7   9   11   7   8   5   11   8   9   5   3   6   2   1   0
# Weighted Adjacency Matrix:
# 0   4   8   4   10   9   12   9   13   10   6   8   7   9   11   11   12   11
# 4   0   4   4   6   5   8   9   10   10   2   4   3   5   7   7   12   11
# 8   4   0   8   2   1   4   10   6   8   6   8   7   9   8   9   10   9
# 1   4   8   0   10   9   12   5   9   6   6   8   7   9   11   11   8   7
# 10   6   2   10   0   3   2   8   5   6   8   9   9   8   6   7   8   7
# 9   5   1   9   3   0   3   9   5   7   7   8   8   9   7   8   9   8
# 11   8   4   10   2   3   0   6   3   4   9   7   10   6   4   5   6   5
# 6   9   11   5   10   10   8   0   5   2   11   13   12   14   12   13   4   3
# 10   10   6   9   5   5   3   5   0   3   12   10   13   9   7   8   5   4
# 7   10   9   6   8   8   6   2   3   0   12   13   13   12   10   11   2   1
# 6   2   6   6   8   7   9   11   12   12   0   2   1   3   5   5   14   13
# 8   4   8   8   9   8   7   13   10   11   2   0   3   1   3   3   13   12
# 7   3   7   7   9   8   9   12   12   13   1   3   0   4   5   4   15   14
# 9   5   9   9   8   9   6   12   9   10   3   1   4   0   2   2   12   11
# 11   7   8   11   6   7   4   10   7   8   5   3   6   2   0   1   10   9
# 11   7   9   11   7   8   5   11   8   9   5   3   6   2   1   0   11   10
# 9   12   11   8   10   10   8   4   5   2   14   15   15   14   12   13   0   3
# 8   11   10   7   9   9   7   3   4   1   13   14   14   13   11   12   3   0
# Weighted Adjacency Matrix:
# 0   4   8   4   10   9   12   9   13   10   6   8   7   9   11   11   12   11   13   13
# 4   0   4   4   6   5   8   9   10   10   2   4   3   5   7   7   12   11   13   9
# 8   4   0   8   2   1   4   10   6   8   6   8   7   9   8   9   10   9   11   11
# 1   4   8   0   10   9   12   5   9   6   6   8   7   9   11   11   8   7   9   11
# 10   6   2   10   0   3   2   8   5   6   8   9   9   8   6   7   8   7   9   9
# 9   5   1   9   3   0   3   9   5   7   7   8   8   9   7   8   9   8   10   10
# 11   8   4   10   2   3   0   6   3   4   9   7   10   6   4   5   6   5   7   7
# 6   9   11   5   10   10   8   0   5   2   11   13   12   12   10   9   4   3   5   7
# 10   10   6   9   5   5   3   5   0   3   12   10   13   9   7   8   5   4   6   8
# 7   10   9   6   8   8   6   2   3   0   12   11   13   10   8   7   2   1   3   5
# 6   2   6   6   8   7   9   11   12   12   0   2   1   3   5   5   14   11   13   7
# 8   4   8   8   9   8   7   13   10   11   2   0   3   1   3   4   13   10   12   6
# 7   3   7   7   9   8   9   12   12   11   1   3   0   4   5   4   13   10   12   6
# 9   5   9   9   8   9   6   12   9   10   3   1   4   0   2   3   12   9   11   5
# 11   7   8   11   6   7   4   10   7   8   5   3   6   2   0   1   10   7   9   3
# 12   8   9   12   7   8   5   9   8   7   6   4   7   3   1   0   9   6   8   2
# 9   12   11   8   10   10   8   4   5   2   14   13   15   12   10   9   0   3   5   7
# 8   11   10   7   9   9   7   3   4   1   12   10   13   9   7   6   3   0   2   4
# 10   13   12   9   11   11   9   5   6   3   14   12   15   11   9   8   5   2   0   6
# 12   10   11   11   9   10   7   7   8   5   8   6   9   5   3   2   7   4   6   0

# %%
import math
import time

def time_ms():
    return time.time() * 1000

class Graph():   
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)]
                      for row in range(vertices)]    
    def addEdge(self, u, v, w):
        self.graph[u][v] = w
        self.graph[v][u] = w
    def printSolution(self, dist):
        print("Vertex \t Distance")
        for node in range(self.V):
            print(node, "\t", dist[node])
    #Find the vertex with minimum distance value, from the set of vertices not yet included in SPT
    def minDistance(self, dist, SPT):
        min = math.inf
        for v in range(self.V):
            if dist[v] < min and SPT[v] == False:
                min = dist[v]
                min_index = v
        return min_index
    def dijkstra(self, src):
        dist = [math.inf] * self.V
        dist[src] = 0
        SPT = [False] * self.V
        for _ in range(self.V):
            # Pick the minimum distance vertex from the set of vertices not yet processed.
            u = self.minDistance(dist, SPT)
            SPT[u] = True # Put the minimum distance vertex in the shortest path tree
            # Update dist value of the adjacent vertices of the picked vertex only if the current
            # distance is greater than new distance and the vertex in not in the shortest path tree
            for v in range(self.V):
                if (self.graph[u][v] > 0 and
                   SPT[v] == False and dist[v] > dist[u] + self.graph[u][v]):
                   dist[v] = min(dist[v],dist[u] + self.graph[u][v])
        self.printSolution(dist)

# %%
import time
import matplotlib.pyplot as plt


g1 = Graph(6)
g1.addEdge(0, 1, 4), g1.addEdge(0, 3, 4),
g1.addEdge(1, 0, 2), g1.addEdge(1, 2, 4), g1.addEdge(1, 3, 4), 
g1.addEdge(2, 1, 4), g1.addEdge(2, 4, 10), g1.addEdge(2, 5, 1),
g1.addEdge(3, 0, 1), g1.addEdge(3, 1, 4), g1.addEdge(3, 5, 4)
g1.addEdge(4, 2, 10),
g1.addEdge(5, 2, 1), g1.addEdge(5, 3, 4)
start1 = time_ms()  
dist1 = g1.dijkstra(0)
end1 = time_ms()
        
g = Graph(8)
g.addEdge(0, 1, 4), g.addEdge(0, 3, 2),
g.addEdge(1, 0, 2), g.addEdge(1, 2, 4), g.addEdge(1, 3, 4), 
g.addEdge(2, 1, 4), g.addEdge(2, 4, 10), g.addEdge(2, 5, 1),
g.addEdge(3, 0, 2), g.addEdge(3, 1, 4), g.addEdge(3, 7, 5),
g.addEdge(4, 2, 2), g.addEdge(4, 6, 12),
g.addEdge(5, 2, 1), g.addEdge(5, 6, 3), g.addEdge(5, 7, 6)
g.addEdge(6, 4, 4), g.addEdge(6, 5, 1), 
g.addEdge(7, 3, 5), g.addEdge(7, 5, 6)
start2 = time_ms()  
dist2 = g.dijkstra(0)
end2 = time_ms()

g3 = Graph(10)
g3.addEdge(0, 1, 4), g3.addEdge(0, 3, 4),
g3.addEdge(1, 0, 4), g3.addEdge(1, 2, 4), g3.addEdge(1, 3, 4), g3.addEdge(1, 9, 7),
g3.addEdge(2, 1, 4), g3.addEdge(2, 4, 2), g3.addEdge(2, 5, 1),
g3.addEdge(3, 0, 1), g3.addEdge(3, 1, 4), g3.addEdge(3, 7, 4), g3.addEdge(3, 9, 6),
g3.addEdge(4, 2, 2), g3.addEdge(4, 6, 2),
g3.addEdge(5, 2, 1), g3.addEdge(5, 6, 3), g3.addEdge(5, 8, 5),
g3.addEdge(6, 4, 2), g3.addEdge(6, 5, 3), g3.addEdge(6, 8, 3), g3.addEdge(6, 9, 4),
g3.addEdge(7, 3, 4), g3.addEdge(7, 9, 1), 
g3.addEdge(8, 5, 5), g3.addEdge(8, 6, 3), g3.addEdge(8, 9, 3),
g3.addEdge(9, 1, 7), g3.addEdge(9, 3, 6), g3.addEdge(9, 7, 1), g3.addEdge(9, 8, 3)
start3 = time_ms()  
dist3 = g3.dijkstra(0)
end3 = time_ms()

g4 = Graph(12)
g4.addEdge(0, 1, 4), g4.addEdge(0, 3, 4),
g4.addEdge(1, 0, 4), g4.addEdge(1, 2, 4), g4.addEdge(1, 3, 4), g4.addEdge(1, 9, 10), g4.addEdge(1, 10, 2),
g4.addEdge(2, 1, 4), g4.addEdge(2, 4, 5), g4.addEdge(2, 5, 1),
g4.addEdge(3, 0, 1), g4.addEdge(3, 1, 4), g4.addEdge(3, 7, 5), g4.addEdge(3, 9, 6),
g4.addEdge(4, 2, 5), g4.addEdge(4, 6, 2), 
g4.addEdge(5, 2, 1), g4.addEdge(5, 6, 3), g4.addEdge(5, 8, 5), g4.addEdge(5, 11, 8),
g4.addEdge(6, 4, 2), g4.addEdge(6, 5, 3), g4.addEdge(6, 8, 3), g4.addEdge(6, 9, 4), 
g4.addEdge(7, 3, 5), g4.addEdge(7, 9, 2), g4.addEdge(7, 11, 2)
g4.addEdge(8, 5, 5), g4.addEdge(8, 6, 3), g4.addEdge(8, 9, 3),
g4.addEdge(9, 1, 10), g4.addEdge(9, 3, 6), g4.addEdge(9, 7, 2), g4.addEdge(9, 8, 3), 
g4.addEdge(10, 1, 2), g4.addEdge(10, 11, 2)
g4.addEdge(11, 5, 8),  g4.addEdge(11, 7, 2), g4.addEdge(11, 10, 2)
start4 = time_ms()  
dist4 = g4.dijkstra(0)
end4 = time_ms()

g5 = Graph(14)
g5.addEdge(0, 1, 4), g5.addEdge(0, 3, 4),
g5.addEdge(1, 0, 4), g5.addEdge(1, 2, 4), g5.addEdge(1, 3, 4), g5.addEdge(1, 9, 10), g5.addEdge(1, 10, 2), g5.addEdge(1, 13, 10)
g5.addEdge(2, 1, 4), g5.addEdge(2, 4, 2), g5.addEdge(2, 5, 1),
g5.addEdge(3, 0, 1), g5.addEdge(3, 1, 4), g5.addEdge(3, 7, 5), g5.addEdge(3, 9, 6),
g5.addEdge(4, 2, 2), g5.addEdge(4, 6, 2), g5.addEdge(4, 12, 12),
g5.addEdge(5, 2, 1), g5.addEdge(5, 6, 4), g5.addEdge(5, 7, 2),g5.addEdge(5, 8, 5), g5.addEdge(5, 11, 8),
g5.addEdge(6, 4, 2), g5.addEdge(6, 5, 4), g5.addEdge(6, 8, 3), g5.addEdge(6, 9, 4),
g5.addEdge(7, 3, 5), g5.addEdge(7, 9, 2), g5.addEdge(7, 5, 2)
g5.addEdge(8, 5, 5), g5.addEdge(8, 6, 3), g5.addEdge(8, 9, 3),
g5.addEdge(9, 1, 10), g5.addEdge(9, 3, 6), g5.addEdge(9, 7, 2), g5.addEdge(9, 8, 3)
g5.addEdge(10, 1, 2), g5.addEdge(10, 11, 2), g5.addEdge(10, 12, 1), 
g5.addEdge(11, 5, 8), g5.addEdge(11, 10, 2), g5.addEdge(11, 12, 3), g5.addEdge(11, 13, 1), 
g5.addEdge(12, 4, 12), g5.addEdge(12, 10, 1), g5.addEdge(12, 11, 3)
g5.addEdge(13, 11, 1), g5.addEdge(13, 1, 10)
start5 = time_ms()  
dist5 = g5.dijkstra(0)
end5 = time_ms()

g6 = Graph(16)
g6.addEdge(0, 1, 4), g6.addEdge(0, 3, 4),
g6.addEdge(1, 0, 4), g6.addEdge(1, 2, 4), g6.addEdge(1, 3, 4), g6.addEdge(1, 9, 10), g6.addEdge(1, 10, 2),
g6.addEdge(2, 1, 4), g6.addEdge(2, 4, 2), g6.addEdge(2, 5, 1),
g6.addEdge(3, 0, 1), g6.addEdge(3, 1, 4), g6.addEdge(3, 7, 5), g6.addEdge(3, 9, 6),
g6.addEdge(4, 2, 2), g6.addEdge(4, 6, 2), g6.addEdge(4, 12, 12), g6.addEdge(4, 14, 6),
g6.addEdge(5, 2, 1), g6.addEdge(5, 6, 3), g6.addEdge(5, 8, 5), g6.addEdge(5, 11, 8),
g6.addEdge(6, 4, 2), g6.addEdge(6, 5, 3), g6.addEdge(6, 8, 3), g6.addEdge(6, 9, 4), g6.addEdge(6, 14, 4),
g6.addEdge(7, 3, 5), g6.addEdge(7, 9, 2),
g6.addEdge(8, 5, 5), g6.addEdge(8, 6, 3), g6.addEdge(8, 9, 3),
g6.addEdge(9, 1, 10), g6.addEdge(9, 3, 6), g6.addEdge(9, 7, 2), g6.addEdge(9, 8, 3),
g6.addEdge(10, 1, 2), g6.addEdge(10, 11, 2), g6.addEdge(10, 12, 1), 
g6.addEdge(11, 5, 8), g6.addEdge(11, 10, 2), g6.addEdge(11, 12, 3), g6.addEdge(11, 13, 1), 
g6.addEdge(12, 4, 12), g6.addEdge(12, 10, 1), g6.addEdge(12, 11, 3), g6.addEdge(12, 15, 4),
g6.addEdge(13, 11, 1), g6.addEdge(13, 14, 2), g6.addEdge(13, 15, 2)
g6.addEdge(14, 4, 6), g6.addEdge(14, 6, 4), g6.addEdge(14, 13, 2), g6.addEdge(14, 15, 1)
g6.addEdge(15, 14, 1), g6.addEdge(15, 13, 2)
start6 = time_ms()  
dist6 = g6.dijkstra(0)
end6 = time_ms()

g7 = Graph(18)
g7.addEdge(0, 1, 4), g7.addEdge(0, 3, 4),
g7.addEdge(1, 0, 4), g7.addEdge(1, 2, 4), g7.addEdge(1, 3, 4), g7.addEdge(1, 9, 10), g7.addEdge(1, 10, 2),
g7.addEdge(2, 1, 4), g7.addEdge(2, 4, 2), g7.addEdge(2, 5, 1),
g7.addEdge(3, 0, 1), g7.addEdge(3, 1, 4), g7.addEdge(3, 7, 5), g7.addEdge(3, 9, 6),
g7.addEdge(4, 2, 2), g7.addEdge(4, 6, 2), g7.addEdge(4, 12, 12), g7.addEdge(4, 14, 6), g7.addEdge(4, 17, 16)
g7.addEdge(5, 2, 1), g7.addEdge(5, 6, 3), g7.addEdge(5, 8, 5), g7.addEdge(5, 11, 8),
g7.addEdge(6, 4, 2), g7.addEdge(6, 5, 3), g7.addEdge(6, 8, 3), g7.addEdge(6, 9, 4), g7.addEdge(6, 14, 4),
g7.addEdge(7, 3, 5), g7.addEdge(7, 9, 2), g7.addEdge(7, 16, 6)
g7.addEdge(8, 5, 5), g7.addEdge(8, 6, 3), g7.addEdge(8, 9, 3),
g7.addEdge(9, 1, 10), g7.addEdge(9, 3, 6), g7.addEdge(9, 7, 2), g7.addEdge(9, 8, 3), g7.addEdge(9, 16, 2), g7.addEdge(9, 17, 1),
g7.addEdge(10, 1, 2), g7.addEdge(10, 11, 2), g7.addEdge(10, 12, 1), 
g7.addEdge(11, 5, 8), g7.addEdge(11, 10, 2), g7.addEdge(11, 12, 3), g7.addEdge(11, 13, 1), 
g7.addEdge(12, 4, 12), g7.addEdge(12, 10, 1), g7.addEdge(12, 11, 3), g7.addEdge(12, 15, 4),
g7.addEdge(13, 11, 1), g7.addEdge(13, 14, 2), g7.addEdge(13, 15, 2)
g7.addEdge(14, 4, 6), g7.addEdge(14, 6, 4), g7.addEdge(14, 13, 2), g7.addEdge(14, 15, 1),
g7.addEdge(15, 14, 1), g7.addEdge(15, 14, 1), g7.addEdge(15, 13, 2)
g7.addEdge(16, 7, 6), g7.addEdge(16, 9, 2), 
g7.addEdge(17, 9, 1), g7.addEdge(17, 4, 16)
start7 = time_ms()  
dist7 = g7.dijkstra(0)
end7 = time_ms()


g8 = Graph(20)
g8.addEdge(0, 1, 4), g8.addEdge(0, 3, 4),
g8.addEdge(1, 0, 4), g8.addEdge(1, 2, 4), g8.addEdge(1, 3, 4), g8.addEdge(1, 9, 10), g8.addEdge(1, 10, 2),
g8.addEdge(2, 1, 4), g8.addEdge(2, 4, 2), g8.addEdge(2, 5, 1),
g8.addEdge(3, 0, 1), g8.addEdge(3, 1, 4), g8.addEdge(3, 7, 5), g8.addEdge(3, 9, 6),
g8.addEdge(4, 2, 2), g8.addEdge(4, 6, 2), g8.addEdge(4, 12, 12), g8.addEdge(4, 14, 6),
g8.addEdge(5, 2, 1), g8.addEdge(5, 6, 3), g8.addEdge(5, 8, 5), g8.addEdge(5, 11, 8),
g8.addEdge(6, 4, 2), g8.addEdge(6, 5, 3), g8.addEdge(6, 8, 3), g8.addEdge(6, 9, 4), g8.addEdge(6, 14, 4),
g8.addEdge(7, 3, 5), g8.addEdge(7, 9, 2), g8.addEdge(7, 16, 6)
g8.addEdge(8, 5, 5), g8.addEdge(8, 6, 3), g8.addEdge(8, 9, 3),
g8.addEdge(9, 1, 10), g8.addEdge(9, 3, 6), g8.addEdge(9, 7, 2), g8.addEdge(9, 8, 3), g8.addEdge(9, 16, 2), g8.addEdge(9, 17, 1), g8.addEdge(9, 18, 5),
g8.addEdge(10, 1, 2), g8.addEdge(10, 11, 2), g8.addEdge(10, 12, 1), 
g8.addEdge(11, 5, 8), g8.addEdge(11, 10, 2), g8.addEdge(11, 12, 3), g8.addEdge(11, 13, 1), 
g8.addEdge(12, 4, 12), g8.addEdge(12, 10, 1), g8.addEdge(12, 11, 3), g8.addEdge(12, 15, 4),
g8.addEdge(13, 11, 1), g8.addEdge(13, 14, 2),
g8.addEdge(14, 4, 6), g8.addEdge(14, 6, 4), g8.addEdge(14, 13, 2), g8.addEdge(14, 15, 1), g8.addEdge(14, 18, 11),
g8.addEdge(15, 14, 1), g8.addEdge(15, 19, 2),
g8.addEdge(16, 7, 6), g8.addEdge(16, 9, 2), 
g8.addEdge(17, 9, 1), g8.addEdge(17, 18, 2), g8.addEdge(17, 19, 4),
g8.addEdge(18, 9, 5), g8.addEdge(18, 14, 11),  g8.addEdge(18, 17, 2)
g8.addEdge(19, 15, 2),  g8.addEdge(19, 17, 4)
start8 = time_ms()  
dist8 = g8.dijkstra(0)
end8 = time_ms()

x = [ 6, 8, 10, 12, 14, 16, 18, 20]
y1 = [ end1 - start1, end2-start2, end3 - start3, end4 - start4, end5 - start5, end6 - start6, end7 - start7, end8 - start8]
plt.plot(x, y2, marker='o')
plt.title('Dijkstra')
plt.show()
# Out:
# Vertex 	 Distance
# 0 	 0
# 1 	 2
# 2 	 6
# 3 	 1
# 4 	 16
# 5 	 5
# Vertex 	 Distance
# 0 	 0
# 1 	 2
# 2 	 6
# 3 	 2
# 4 	 8
# 5 	 7
# 6 	 8
# 7 	 7
# Vertex 	 Distance
# 0 	 0
# 1 	 4
# 2 	 8
# 3 	 1
# 4 	 10
# 5 	 9
# 6 	 10
# 7 	 5
# 8 	 9
# 9 	 6
# Vertex 	 Distance
# 0 	 0
# 1 	 4
# 2 	 8
# 3 	 1
# 4 	 13
# 5 	 9
# 6 	 11
# 7 	 6
# 8 	 10
# 9 	 7
# 10 	 6
# 11 	 8
# Vertex 	 Distance
# 0 	 0
# 1 	 4
# 2 	 8
# 3 	 1
# 4 	 10
# 5 	 8
# 6 	 11
# 7 	 6
# 8 	 10
# 9 	 7
# 10 	 6
# 11 	 8
# 12 	 7
# 13 	 9
# Vertex 	 Distance
# 0 	 0
# 1 	 4
# 2 	 8
# 3 	 1
# 4 	 10
# 5 	 9
# 6 	 11
# 7 	 6
# 8 	 10
# 9 	 7
# 10 	 6
# 11 	 8
# 12 	 7
# 13 	 9
# 14 	 11
# 15 	 11
# Vertex 	 Distance
# 0 	 0
# 1 	 4
# 2 	 8
# 3 	 1
# 4 	 10
# 5 	 9
# 6 	 11
# 7 	 6
# 8 	 10
# 9 	 7
# 10 	 6
# 11 	 8
# 12 	 7
# 13 	 9
# 14 	 11
# 15 	 11
# 16 	 9
# 17 	 8
# Vertex 	 Distance
# 0 	 0
# 1 	 4
# 2 	 8
# 3 	 1
# 4 	 10
# 5 	 9
# 6 	 11
# 7 	 6
# 8 	 10
# 9 	 7
# 10 	 6
# 11 	 8
# 12 	 7
# 13 	 9
# 14 	 11
# 15 	 11
# 16 	 9
# 17 	 8
# 18 	 10
# 19 	 12

# %%
plt.plot(x, y1, color='b', label='Floyd')
plt.plot(x, y2, color='g', label='Dijkstra')
  
plt.title("Execution time")
  
plt.legend()

plt.show()
